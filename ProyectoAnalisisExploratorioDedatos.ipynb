# %% [markdown]
# # Conociendo nuestros datos de pingüinos. 🗺🧭🐧

# %% [markdown]
# ## Instalar librerías necesarias

# %% [markdown]
# ```
# !pip install --upgrade pip
# ```
# ```
# !pip install palmerpenguins==0.1.4 numpy==1.23.4 pandas==1.5.1 seaborn==0.12.1 matplotlib==3.6.0 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.1.2 pyjanitor==0.23.1 session-info
# ```

# %% [markdown]
# ## Importar librerías

# %%
pip install palmerpenguins numpy pandas seaborn matplotlib empiricaldist statsmodels sklearn pyjanitor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached palmerpenguins-0.1.4-py3-none-any.whl (17 kB)
# ...
#   Using cached empiricaldist-0.6.8.tar.gz (12 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached statsmodels-0.13.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.4/158.4 kB 855.6 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# ...
#   Using cached multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# ...
#   Using cached pandas_flavor-0.5.0-py3-none-any.whl (7.1 kB)
# ...
#   Using cached natsort-8.3.1-py3-none-any.whl (38 kB)
# ...
#   Using cached lazy_loader-0.1-py3-none-any.whl (8.6 kB)
# ...
#   Using cached xarray-2023.2.0-py3-none-any.whl (975 kB)
# ...

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss

# %% [markdown]
# ## Establecer apariencia general de los gráficos

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# ## Cargar los datos

# %% [markdown]
# ### Utilizando el paquete `palmerpenguins`

# %% [markdown]
# #### Datos crudos

# %%
raw_penguins_df = palmerpenguins.load_penguins_raw()
raw_penguins_df
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %% [markdown]
# #### Datos previamente procesados

# %%
preprocess_penguins_df = palmerpenguins.load_penguins()
preprocess_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# ### Utilizando los conjuntos de datos de `seaborn`

# %%
sns.load_dataset('penguins')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ### Utilizando la interfaz de `Deepnote`
#
# Links de importación de datos:
#
# - [Conjunto de datos crudos](https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins_raw.csv).
# - [Conjunto de datos previamente procesados](https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv).

# %% [markdown]
# # Colecta y validación de datos

# %% [markdown]
# ## ¿Qué tipo de dato son las variables del conjunto de datos?

# %%
preprocess_penguins_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %% [markdown]
# ## ¿Cuántas variables de cada tipo de dato tenemos en el conjunto de datos?

# %%
preprocess_penguins_df.dtypes.value_counts()
# Out:
# float64    4
# object     3
# int64      1
# dtype: int64

# %% [markdown]
# ## ¿Cuántas variables y observaciones tenemos en el conjunto de datos?

# %%
preprocess_penguins_df.shape
# Out:
# (344, 8)

# %% [markdown]
# ## ¿Existen valores nulos explícitos en el conjunto de datos?

# %%
preprocess_penguins_df.isnull().any()
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %% [markdown]
# ## De tener observaciones con valores nulos, ¿cuántas tenemos por cada variable?

# %%
preprocess_penguins_df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# ## ¿Cuántos valores nulos tenemos en total en el conjunto de datos?

# %%
preprocess_penguins_df.isnull().sum().sum()
# Out:
# 19

# %% [markdown]
# ## ¿Cuál es la proporción de valores nulos por cada variable?

# %%
# pipe()
preprocess_penguins_df.isnull().melt().pipe(
    lambda df : (
    sns.displot(
    data=df,
    y='variable',
    hue='value',
    multiple='fill',
    aspect=2
    )
    )
)

# %% [markdown]
# ## ¿Cómo podemos visualizar los valores nulos en todo el conjunto de datos?

# %%
#transpose() transforma las filas en clomunas y las columnas en filas
preprocess_penguins_df.isnull().transpose().pipe(
    lambda df:(
    sns.heatmap(
    data=df
    )
    )
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## ¿Cuántas observaciones perdemos si eliminamos los datos faltantes?

# %%
processed_penguins = preprocess_penguins_df.dropna()
processed_penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# # Conteos y proporciones

# %% [markdown]
# ## Preludio: ¿Qué estadísticos describen el conjunto de datos?

# %% [markdown]
# ### Todas las variables

# %%
processed_penguins.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    333.000000   333   333.000000
# ...

# %% [markdown]
# ### Solo las numéricas

# %%
processed_penguins.describe(include=[np.number])
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# ### Solo categóricas - 1

# %%
processed_penguins.describe(include='object')
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# ### Solo categóricas - 2

# %%
#con este codigo ya no los llamo con object sino con category
processed_penguins.astype({
    'species' : 'category',
    'island' : 'category',
    'sex' : 'category'
}).describe(include='category')
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# ## ¿Cómo visualizar los conteos?

# %% [markdown]
# ### Pandas

# %%
processed_penguins.species.value_counts().plot(
    kind='bar'
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Seaborn

# %%
sns.catplot(
    data=processed_penguins,
    x='species',
    kind='count',
    palette=penguin_color
)

# %%
#reset_index() funciona para que seaborn pueda interpretar la tabla
processed_penguins.value_counts('species',sort=True).reset_index(name='count').pipe(
    lambda df :(
    sns.barplot(
    data=df,
    x='species',
    y='count',
    palette=penguin_color
    )
    )
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %% [markdown]
# ### ¿Cómo visualizar las proporciones?

# %%
processed_penguins.add_column('x', '').pipe(
    lambda df :(
    sns.displot(
    data=df,
    x='x',
    hue='species',
    multiple='fill',
    palette=penguin_color
    )
    )
)

# %%
#islands
preprocess_penguins_df.value_counts('island',sort=True).reset_index(name='count').pipe(
    lambda df:(
    sns.barplot(
    data=df,
    x='island',
    y='count'
    )
    )
)
# Out:
# <AxesSubplot: xlabel='island', ylabel='count'>

# %% [markdown]
# # Medidas de tendencia central

# %% [markdown]
# ## Media o promedio

# %%
#promedio de los picos
processed_penguins.bill_depth_mm.mean()
# Out:
# 17.164864864864867

# %%
np.mean(processed_penguins.bill_depth_mm)
# Out:
# 17.164864864864867

# %%
#Promedio de todas las variables numericas
processed_penguins.mean()
# Out:
# /tmp/ipykernel_390/2525411746.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.mean()
# bill_length_mm         43.992793
# bill_depth_mm          17.164865
# flipper_length_mm     200.966967
# body_mass_g          4207.057057
# year                 2008.042042
# dtype: float64

# %% [markdown]
# ## Mediana

# %%
processed_penguins.median()
# Out:
# /tmp/ipykernel_390/305757089.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.median()
# bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# year                 2008.0
# dtype: float64

# %% [markdown]
# ## Moda

# %%
processed_penguins.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex  year
# 0       3800.0  male  2009

# %%
processed_penguins.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# # Medidas de dispersión

# %% [markdown]
# ## ¿Cuál es el valor máximo de las variables?

# %%
processed_penguins.max(numeric_only=True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# year                 2009.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el valor mínimo de las variables?

# %%
processed_penguins.min(numeric_only=True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# year                 2007.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el rango de las variables?

# %%
processed_penguins.max(numeric_only=True) - processed_penguins.min(numeric_only=True)
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es la desviación estándar de las variables?

# %%
processed_penguins.std()
# Out:
# /tmp/ipykernel_390/3334302567.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.std()
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# year                   0.812944
# dtype: float64

# %%
#cuando a la media le sumo y le resto la desviacion standar estoy obteniendo un rango que me toma el 65% de los datos
processed_penguins.mean() + processed_penguins.std()
# Out:
# /tmp/ipykernel_390/2723947523.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.mean() + processed_penguins.std()
# /tmp/ipykernel_390/2723947523.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.mean() + processed_penguins.std()
# bill_length_mm         49.461461
# bill_depth_mm          19.134100
# flipper_length_mm     214.982732
# body_mass_g          5012.272859
# year                 2008.854986
# dtype: float64

# %%
processed_penguins.mean() - processed_penguins.std()
# Out:
# /tmp/ipykernel_390/3872019319.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.mean() - processed_penguins.std()
# /tmp/ipykernel_390/3872019319.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.mean() - processed_penguins.std()
# bill_length_mm         38.524124
# bill_depth_mm          15.195629
# flipper_length_mm     186.951202
# body_mass_g          3401.841255
# year                 2007.229098
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el rango intercuartílico?

# %%
processed_penguins.quantile(0.75)
# Out:
# /tmp/ipykernel_390/3275970463.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.quantile(0.75)
# bill_length_mm         48.6
# bill_depth_mm          18.7
# flipper_length_mm     213.0
# body_mass_g          4775.0
# year                 2009.0
# Name: 0.75, dtype: float64

# %%
#rango intercuantilico me calcula el 50% de los datos
processed_penguins.quantile(0.75) - processed_penguins.quantile(0.25)
# Out:
# /tmp/ipykernel_390/1884968737.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.quantile(0.75) - processed_penguins.quantile(0.25)
# bill_length_mm          9.1
# bill_depth_mm           3.1
# flipper_length_mm      23.0
# body_mass_g          1225.0
# year                    2.0
# dtype: float64

# %%
(
processed_penguins.quantile(q = [0.75,0.50,0.25])
.transpose()
.rename_axis('variable')
.reset_index()
.assign(
    iqr=lambda df: df[0.75] - df[0.25]
)
)
# Out:
# /tmp/ipykernel_390/1116515655.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.quantile(q = [0.75,0.50,0.25])
#             variable    0.75     0.5    0.25     iqr
# 0     bill_length_mm    48.6    44.5    39.5     9.1
# 1      bill_depth_mm    18.7    17.3    15.6     3.1
# 2  flipper_length_mm   213.0   197.0   190.0    23.0
# 3        body_mass_g  4775.0  4050.0  3550.0  1225.0
# 4               year  2009.0  2008.0  2007.0     2.0

# %% [markdown]
# ## ¿Cómo puedo visualizar la distribución de una variable?

# %% [markdown]
# ### Histograma

# %%
sns.histplot(data=processed_penguins,
             x='flipper_length_mm')
plt.axvline(#añado una linea punteada donde existe la media 
    x=processed_penguins.flipper_length_mm.mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)

# %% [markdown]
# ### Diagrama de caja / boxplot

# %%
sns.boxplot(data=processed_penguins, x='flipper_length_mm')
# Out:
# <AxesSubplot: xlabel='flipper_length_mm'>

# %% [markdown]
# ### Limitaciones

# %%
def freedman_diaconis_bindwidth(x: pd.Series) -> float:
    """Find optimal bindwidth using Freedman-Diaconis rule."""

    IQR = x.quantile(0.75) - x.quantile(0.25)
    N = x.size

    return 2 * IQR / N ** (1 / 3)

# %% [markdown]
# # Distribuciones: PMFs, CDFs y PDFs

# %% [markdown]
# ## Funciones de probabilidad de masas (PMFs)

# %% [markdown]
# ### Utilizando `seaborn`

# %%
#patametro stat me es capaz de calcularme la probabilidad de que algun dato ocurra
sns.histplot(data =processed_penguins, x='flipper_length_mm',binwidth=1,stat='probability')
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Probability'>

# %% [markdown]
# ### Utilizando `empiricaldist`

# %%
pmf_flipper_length = empiricaldist.Pmf.from_seq(
    processed_penguins.flipper_length_mm,
    normalize=True
)

# %%
pmf_flipper_length.bar()

# %%
#con esta libreria a un objeto le puedo preguntar cual es la probabilidad de algun valor con tan solo escribirlo entre parentesis
pmf_flipper_length(190)
# Out:
# 0.06306306306306306

# %%
processed_penguins.flipper_length_mm.max()
# Out:
# 231.0

# %% [markdown]
# ## Funciones empirícas de probabilidad acumulada (ECDFs)

# %% [markdown]
# ### Utilizando `seaborn`

# %%
#nos dice la probabilidad acumulada de que un evento suceda
sns.ecdfplot(
    data=processed_penguins,
    x='flipper_length_mm'
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ### Utilizando `empiricaldist`

# %%
cdf_flipper_length = empiricaldist.Cdf.from_seq(
    processed_penguins.flipper_length_mm,
    normalize=True
)

# %%
cdf_flipper_length.plot()

q = 200
p = cdf_flipper_length.forward(q)

plt.vlines(
    x=q,
    ymin=0,
    ymax=p,
    color='black',
    linestyle='dashed'
)

plt.hlines(
    y=p,
    xmin=pmf_flipper_length.qs[0],
    xmax=q,
    color='black',
    linestyle='dashed'
)

plt.plot(q,p, 'ro')

# %%
cdf_flipper_length.step ( )
p_1 = 8.25 # Specify probability
P_2 = 8.75
ps = ( 0.25 , 0.75 ) # Rango intercuartil
qs = cdf_flipper_length.inverse(ps)
plt.vlines (
    x = qs,
    ymin = 0,
    ymax=ps,
    color='black',
    linestyle='dashed'
)

plt.hlines(
   y=ps,
   xmin=pmf_flipper_length.qs[0],
   xmax=qs,
   color='black',
   linestyle='dashed'
)

plt.scatter(
   x=qs,
   y=ps,
   color='red',
   zorder=2
)

# %% [markdown]
# ### Comparando distribuciones

# %%
sns.ecdfplot(
data=processed_penguins,
x='flipper_length_mm',
hue='species')
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ## Funciones de densidad de probabilidad

# %%
sns.kdeplot(
    data=processed_penguins,
    x='flipper_length_mm',
    bw_method=0.1 # Method for determining the smoothing bandwidth to use
)
#Probabilidad de que un pinguino tenga una longitud determinada de ala
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Density'>

# %%
stats = processed_penguins.body_mass_g.describe()#stats de body mass
stats
# Out:
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
xs = np.linspace(stats['min'],stats['max'])#tomo los datos como si se comportaran de una forma normal teoricamente
ys = scipy.stats.norm(stats['mean'],stats['std']).cdf(xs)#

plt.plot(xs,ys,linestyle='dashed')

empiricaldist.Cdf.from_seq(
    processed_penguins.body_mass_g,
    normalize=True
).plot()

#con empiricaldist puedo ver el comportamiento real de mis datos y lo comparo con la curva teorica
# Out:
# <AxesSubplot: >

# %%
xs = np.linspace(stats['min'],stats['max'])#tomo los datos como si se comportaran de una forma normal teoricamente
ys = scipy.stats.norm(stats['mean'],stats['std']).pdf(xs)#

plt.plot(xs,ys,linestyle='dashed')

sns.kdeplot(
    data=processed_penguins,
    x='body_mass_g'
)
#podemos ver que no es una distribucion normal y esta esta segada hacia la izquierda
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# # Ley de los Grandes Números y Teorema del Límite Central

# %% [markdown]
# ## Ley de los Grandes Números

# %%
#la ley de los grandes numeros dice que a medida que aumenta el numero de repeticiones del experimento, la probabilidad experimental tiende a la probabilidad teorica
dice = empiricaldist.Pmf.from_seq([1,2,3,4,5,6])
dice.bar()
#muestra la probabilidad de que que cada numero salga en el dado

# %%
for sample_size in (1e2,1e3,1e4):
    sample_size = int(sample_size)
    values = dice.sample(sample_size)
    sample_Pmf = empiricaldist.Pmf.from_seq(values)
    plt.figure(figsize=(5,5))
    sample_Pmf.bar()
    plt.axhline(y=1/6, color='red',linestyle='dashed')
    plt.ylim(0,0.50)
    plt.title(f'Sample size: {sample_size}')

# %% [markdown]
# ## Teorema del Límite Central

# %%
#teorema de limite central indica que la medida de las muestras tiende aproximadamente a una distribucion normal
processed_penguins.sex.value_counts(normalize=True)
# Out:
# male      0.504505
# female    0.495495
# Name: sex, dtype: float64

# %%
sex_numeric = processed_penguins.sex.replace(['male','female'],[1,0]) #las transformo en variables numericas

# %%
number_samples = 1000
sample_size = 35

np.random.seed(42)

# definimos el DataFrame en blanco con su tamaño definido
samples_df = pd.DataFrame(np.random.randint(1, sample_size, size =(sample_size, number_samples)))
# Le asignamos nombres a las columnas.
col_names = []
for i in range(1, number_samples + 1):    
    col_names.append(f"sample_{i}")
samples_df.columns = col_names


for i in range(1, number_samples + 1):
    sex_numeric_sample = sex_numeric.sample(sample_size, replace=True).to_numpy()    
    sample_name = f"sample_{i}"
    samples_df[sample_name] = sex_numeric_sample

male_population_mean = samples_df.mean().mean()
print(f"El porcentaje estimado de pingüinos machos en la población es: {male_population_mean * 100:.4f}%")
# Out:
# El porcentaje estimado de pingüinos machos en la población es: 50.7343%

# %%
sample_mean_binomial = pd.DataFrame(samples_df.mean(), columns=['sample_mean'])
sns.kdeplot(data=sample_mean_binomial)
plt.axvline(x=sex_numeric.mean(), color = 'red', linestyle='dashed')

# %%
sample_size_experiment = pd.DataFrame(
    [[i, samples_df.iloc[:,0:i].mean().mean().mean()] for i in range(1, number_samples +1)],
    columns=['sample_size', 'estimated_mean']
)

# %%
sns.scatterplot(
    data=sample_size_experiment,
    x='sample_size', y= 'estimated_mean'
)

plt.axhline(
    y=sex_numeric.mean(),
    color='red',
    linestyle='dashed'
)

plt.ylim([sex_numeric.mean() - 0.20, sex_numeric.mean() + 0.20])
# Out:
# (0.30450450450450445, 0.7045045045045044)

# %% [markdown]
# # Estableciendo relaciones: Gráfica de puntos  - Analisis con dos variables

# %%
sns.scatterplot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/2,#transparencia
    s=100 #tamaño de puntos
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.displot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True # que tanto se acumulan los datos en ciertas zonas
)

# %%
sns.displot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True,
    kind='kde'#donde se acumulan los datos por zonas del plano
)

# %%
sns.jointplot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    hue='species'
)

# %% [markdown]
# # Estableciendo relaciones: Gráficos de violín y boxplots

# %%
sns.scatterplot(
    data=processed_penguins,
    x='species',
    y='flipper_length_mm',
    hue='species'

)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.stripplot(
    data=processed_penguins,
    x='species',
    y='flipper_length_mm',
    hue='species'
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
ax = sns.boxplot(
    data=processed_penguins,
    x='species',
    y='flipper_length_mm',
    hue='species'
    )
ax= sns.stripplot(
    data=processed_penguins,
    x='species',
    y='flipper_length_mm',
    hue='species'
)

# %%
ax = sns.violinplot(
    data=processed_penguins,
    x='species',
    y='flipper_length_mm',
    
)

ax = sns.stripplot(
    data=processed_penguins,
    x='species',
    y='flipper_length_mm',
    hue='species'
)

# %%
sns.swarmplot(
    data= processed_penguins,
    x='species',
    y='flipper_length_mm',
    hue='species'
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
ax = sns.violinplot(
    data=processed_penguins,
    x='island',
    y='body_mass_g'
)

ax = sns.swarmplot(
    data=processed_penguins,
    x='island',
    y='body_mass_g'
)

# %% [markdown]
# # Estableciendo relaciones: Matrices de correlación

# %% [markdown]
# ## ¿Existe una correlación lineal entre alguna de nuestras variables?

# %%
processed_penguins.corr()
# Out:
# /tmp/ipykernel_390/3570535190.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
# year                     0.032657      -0.048182           0.151068
#
#                    body_mass_g      year
# bill_length_mm        0.589451  0.032657
# bill_depth_mm        -0.472016 -0.048182
# flipper_length_mm     0.872979  0.151068
# body_mass_g           1.000000  0.021862
# year                  0.021862  1.000000

# %% [markdown]
# ## ¿Cómo puedo visualizar los coeficientes de correlación?

# %%
sns.heatmap(
    data=processed_penguins.corr(),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True,
    cmap= sns.diverging_palette(20,230, as_cmap=True)
)
# Out:
# /tmp/ipykernel_390/4221242575.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins.corr(),
# <AxesSubplot: >

# %%
sns.clustermap(
    data=processed_penguins.corr(),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True,
    cmap= sns.diverging_palette(20,230, as_cmap=True)
)
# Out:
# /tmp/ipykernel_390/3296671927.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins.corr(),

# %% [markdown]
# ## ¿Cómo podría representar una variable categórica como númerica discreta?

# %%
#creo una nueva columna llamada numeric_sec donde a los machos les pongo 1 y a las hembras 0
processed_penguins = (
    processed_penguins.assign(numeric_sex=lambda df: df.sex.replace(['female','male'],[0,1]))
)

# %%
sns.clustermap(
    data=processed_penguins.corr(),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True,
    cmap= sns.diverging_palette(20,230, as_cmap=True)
)
# Out:
# /tmp/ipykernel_390/445342871.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins.corr(),

# %% [markdown]
# ## ¿Cuál es una limitante de los coeficientes de correlación lineal?

# %% [markdown]
# ### Solo nos ayuda a determinar la posible existencia de una correlación lineal; sin embargo, su ausenecia no significa que no exista otro tipo de correlación

# %%
x = np.linspace(-100,100,100)
y = x**2
y += np.random.normal(0,1000,x.size)

sns.scatterplot(
    x=x,
    y=y
)

np.corrcoef(x,y)
#aunque no parecen tener correlacion LINEAL evidentemente tienen una cuadratica y eso se ve analizando los dartos
# Out:
# array([[1.        , 0.03162206],
#        [0.03162206, 1.        ]])

# %%
x = np.linspace(-100,100,100)
y = x**3
y += np.random.normal(0,1000,x.size)

sns.scatterplot(
    x=x,
    y=y
)
np.corrcoef(x,y)

#aunque no parecen tener correlacion LINEAL evidentemente tienen una cubica y eso se ve analizando los dartos
# Out:
# array([[1.       , 0.9165899],
#        [0.9165899, 1.       ]])

# %%
sns.scatterplot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm'
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# ### El coeficiente de correlación no nos habla del impacto de la relación

# %%
np.random.seed(42)
x1 = np.linspace(0,100,100)
y1 = 0.1* x1 +3 + np.random.uniform(-2,2,size=x1.size)

sns.scatterplot(x=x1, y=y1)


x2 = np.linspace(0,100,100)
y2 = 0.5* x1 +1 + np.random.uniform(0,60,size=x2.size)

sns.scatterplot(x=x2, y=y2)

plt.legend(["1","2"])

print(np.corrcoef(x1,y1))
print(np.corrcoef(x2,y2))
# Out:
# [[1.         0.92761617]
#  [0.92761617 1.        ]]
# [[1.         0.67476343]
#  [0.67476343 1.        ]]

# %% [markdown]
# # Estableciendo relaciones: Análisis de regresión simple

# %%
res_1 = scipy.stats.linregress(x=x1, y=y1)
res_2 = scipy.stats.linregress(x=x2, y=y2)

print(res_1, res_2, sep= '\n')
# Out:
# LinregressResult(slope=0.10081969280979615, intercept=2.8397383330230292, rvalue=0.9276161661149585, pvalue=1.0607043467839354e-43, stderr=0.004101050284084736, intercept_stderr=0.2373714102742458)
# LinregressResult(slope=0.5470008424819226, intercept=28.519861265205236, rvalue=0.6747634267657527, pvalue=1.388369987899253e-14, stderr=0.06043657503136455, intercept_stderr=3.498107570885824)

# %%
sns.scatterplot(
    data= processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm'
)

res_penguins = scipy.stats.linregress(
    x=processed_penguins.bill_length_mm,
    y=processed_penguins.bill_depth_mm
)
print(res_penguins)

fx1 = np.array([processed_penguins.bill_length_mm.min(), processed_penguins.bill_length_mm.max()])
fy1 = res_penguins.intercept + res_penguins.slope * fx1

plt.plot(fx1,fy1)
# Out:
# LinregressResult(slope=-0.08232675339862275, intercept=20.786648668433827, rvalue=-0.22862563591302898, pvalue=2.5282897209443435e-05, stderr=0.019268346735778864, intercept_stderr=0.8541730787409804)

# %%
sns.lmplot(
    data= processed_penguins,
    x= 'bill_length_mm',
    y= 'bill_depth_mm',
    height=10
)

# %% [markdown]
# # Limitaciones del análisis de regresión simple

# %% [markdown]
# ## La regresión lineal simple no es simétrica

# %%
x = processed_penguins.bill_length_mm
y = processed_penguins.bill_depth_mm

res_x_y = scipy.stats.linregress(x=x, y=y)
res_y_x = scipy.stats.linregress(x=y, y=x)

print(res_x_y, res_y_x, sep='\n')

sns.scatterplot(
x=x,
y=y
)

fx_1= np.array([x.min(), x.max()])
fy_1= res_x_y.intercept + res_x_y.slope * fx_1

plt.plot(fx_1, fy_1);
# Out:
# LinregressResult(slope=-0.08232675339862275, intercept=20.786648668433827, rvalue=-0.22862563591302898, pvalue=2.5282897209443435e-05, stderr=0.019268346735778864, intercept_stderr=0.8541730787409804)
# LinregressResult(slope=-0.6349051704195019, intercept=54.89085424504755, rvalue=-0.22862563591302898, pvalue=2.5282897209443435e-05, stderr=0.1485977821662331, intercept_stderr=2.5673415135382553)

# %%
sns.scatterplot(
x=y,
y=x
)

fx_2= np.array([y.min(), y.max()])
fy_2= res_y_x.intercept + res_y_x.slope * fx_2

plt.plot(fx_2, fy_2);

# %%
sns.scatterplot(
x=x,
y=y
)
plt.plot(fx_1, fy_1)
plt.plot(fy_2, fx_2);

# %% [markdown]
# ## La regresión no nos dice nada sobre la causalidad, pero existen herramientas para separar las relaciones entre múltiples variables

# %%
(
    smf.ols(
    formula='bill_depth_mm ~ bill_length_mm',
    data= processed_penguins
    )
    .fit()
    .params
)
# Out:
# Intercept         20.786649
# bill_length_mm    -0.082327
# dtype: float64

# %% [markdown]
# # Análisis de regresión múltiple

# %% [markdown]
# ## Olvidé mi báscula para pesar a los pingüinos, ¿cuál sería la mejor forma de capturar ese dato?

# %% [markdown]
# ### Creando modelos

# %% [markdown]
# #### Modelo 1

# %%
model_1 = (
    smf.ols(
       formula = 'body_mass_g ~ bill_length_mm',
       data = processed_penguins
    )
    .fit()
)

model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     176.2
# Date:                Sun, 21 May 2023   Prob (F-statistic):           1.54e-32
# Time:                        15:24:19   Log-Likelihood:                -2629.1
# No. Observations:                 333   AIC:                             5262.
# Df Residuals:                     331   BIC:                             5270.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Modelo 2

# %%
model_2 = (
    smf.ols(
       formula = 'body_mass_g ~ bill_length_mm + bill_depth_mm',
       data = processed_penguins
    )
    .fit()
)

model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     144.8
# Date:                Sun, 21 May 2023   Prob (F-statistic):           7.04e-46
# Time:                        15:24:19   Log-Likelihood:                -2595.2
# No. Observations:                 333   AIC:                             5196.
# Df Residuals:                     330   BIC:                             5208.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Modelo 3

# %%
model_3 = (
    smf.ols(
       formula = 'body_mass_g ~ bill_length_mm + bill_depth_mm + flipper_length_mm',
       data = processed_penguins
    )
    .fit()
)

model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     354.9
# Date:                Sun, 21 May 2023   Prob (F-statistic):          9.26e-103
# Time:                        15:24:19   Log-Likelihood:                -2459.8
# No. Observations:                 333   AIC:                             4928.
# Df Residuals:                     329   BIC:                             4943.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Modelo 4

# %%
model_4 = (
    smf.ols(
       formula = 'body_mass_g ~ bill_length_mm + bill_depth_mm + C(sex)',# como sex es categorica se escribe C(sex)
       data = processed_penguins
    )
    .fit()
)

model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     241.0
# Date:                Sun, 21 May 2023   Prob (F-statistic):           1.10e-82
# Time:                        15:24:19   Log-Likelihood:                -2506.6
# No. Observations:                 333   AIC:                             5021.
# Df Residuals:                     329   BIC:                             5036.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Modelo 5

# %%
model_5 = (
    smf.ols(
       formula = 'body_mass_g ~ flipper_length_mm + C(sex)',
       data = processed_penguins
    )
    .fit()
)

model_5.summary()

#estos modelos solo funcionan si entre las variables existe una alta correlacion
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     684.8
# Date:                Sun, 21 May 2023   Prob (F-statistic):          3.53e-118
# Time:                        15:24:20   Log-Likelihood:                -2427.2
# No. Observations:                 333   AIC:                             4860.
# Df Residuals:                     330   BIC:                             4872.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Visualizando resultados

# %% [markdown]
# #### Creación de tabla de resultados

# %%
models_result = pd.DataFrame(
    dict(
        actual_value = processed_penguins.body_mass_g,
        prediction_model_1 = model_1.predict(),
        prediction_model_2 = model_2.predict(),
        prediction_model_3 = model_3.predict(),
        prediction_model_4 = model_4.predict(),
        prediction_model_5 = model_5.predict(),
        species=processed_penguins.species,
        sex=processed_penguins.sex
    )
)

models_result
# Out:
#      actual_value  prediction_model_1  prediction_model_2  prediction_model_3  \
# 0          3750.0         3782.402961         3617.641192         3204.761227
# 1          3800.0         3817.119665         3836.725580         3436.701722
# 2          3250.0         3886.553073         3809.271371         3906.897032
# 4          3450.0         3574.102738         3350.786581         3816.705772
# 5          3650.0         3799.761313         3356.140070         3696.168128
# ..            ...                 ...                 ...                 ...
# 339        4000.0         5231.825347         4706.954140         4599.187485
# 340        3400.0         4164.286703         4034.121055         4274.552753
# 341        3775.0         4693.716437         4475.927353         3839.563668
# 342        4100.0         4797.866549         4449.296758         4720.740455
# 343        3775.0         4745.791493         4448.061337         4104.268240
#
# ...

# %% [markdown]
# #### ECDFs

# %%
sns.ecdfplot(
    data=models_result.select_columns(['actual_value', 'prediction_model_5'])
)
# Out:
# <AxesSubplot: ylabel='Proportion'>

# %% [markdown]
# #### PDFs

# %%
sns.kdeplot(
    data=models_result,
    cumulative=True #genera curvas suavizadas de tipo acumulativas
)
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# #### ¿Qué pudimos haber encontrado antes de hacer los modelos?

# %%
sns.lmplot(
    data=processed_penguins,
    x='flipper_length_mm',
    y='body_mass_g',
    hue='sex',
    height=10
)

# %% [markdown]
# # Análisis de regresión logística

# %% [markdown]
# ## ¿Podemos crear un modelo que nos ayude a definir si un pingüino es macho o hembra?

# %%
#Modelo logistico de la variable sexo VS longitud de las aletas, ancho del pico, largo del pico, y la isla
smf.logit(
    formula='numeric_sex ~ flipper_length_mm + bill_length_mm + bill_depth_mm + C(island)',
    data=processed_penguins
).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.360900
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            numeric_sex   No. Observations:                  333
# Model:                          Logit   Df Residuals:                      327
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 21 May 2023   Pseudo R-squ.:                  0.4793
# Time:                        15:50:53   Log-Likelihood:                -120.18
# converged:                       True   LL-Null:                       -230.80
# Covariance Type:            nonrobust   LLR p-value:                 8.021e-46
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Exploración de nuestras variables categóricas

# %%
(
    processed_penguins
    .value_counts(['island', 'sex'])
    .reset_index(name='count')
)
# Out:
#       island     sex  count
# 0     Biscoe    male     83
# 1     Biscoe  female     80
# 2      Dream    male     62
# 3      Dream  female     61
# 4  Torgersen  female     24
# 5  Torgersen    male     23

# %% [markdown]
# ## ¿Podemos definir un modelo que nos ayude a identificar si un pingüino pertenece a determinada clase?

# %%
processed_penguins.species.unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
processed_penguins = (
    processed_penguins
    .assign(is_adelie=lambda df: df.species.replace(['Adelie', 'Gentoo', 'Chinstrap'], [1,0,0]))
)

# %%
#Modelo para determinar si un pinguino es adelie segun su sexo y el largo de las aletas
model_is_adelie = smf.logit(
    formula='is_adelie ~ flipper_length_mm + C(sex)',
    data=processed_penguins
).fit()

model_is_adelie.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.355225
#          Iterations 8
# Intercept            40.568368
# C(sex)[T.male]        1.282656
# flipper_length_mm    -0.209705
# dtype: float64

# %%
is_adelie_df_prediction = pd.DataFrame(
    dict(
        actual_adelie = processed_penguins.is_adelie,
        predicted_values = model_is_adelie.predict().round()  #round indica solo si es cero o uno
    )
)

is_adelie_df_prediction
# Out:
#      actual_adelie  predicted_values
# 0                1               1.0
# 1                1               1.0
# 2                1               0.0
# 4                1               1.0
# 5                1               1.0
# ..             ...               ...
# 339              0               0.0
# 340              0               0.0
# 341              0               1.0
# 342              0               0.0
# 343              0               0.0
#
# [333 rows x 2 columns]

# %%
(
    is_adelie_df_prediction
    .value_counts(['actual_adelie', 'predicted_values'])
    .reset_index(name='count')
)
# Out:
#    actual_adelie  predicted_values  count
# 0              0               0.0    151
# 1              1               1.0    129
# 2              0               1.0     36
# 3              1               0.0     17

# %%
print(
    sklearn.metrics.confusion_matrix(
        is_adelie_df_prediction.actual_adelie,
        is_adelie_df_prediction.predicted_values
    )
)

sklearn.metrics.accuracy_score(
    is_adelie_df_prediction.actual_adelie,
    is_adelie_df_prediction.predicted_values
)
# Out:
# [[151  36]
#  [ 17 129]]
# 0.8408408408408409

# %% [markdown]
# # Paradoja de Simpson

# %%
sns.scatterplot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm'
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.lmplot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    height= 10,
    hue= 'species'
)

# %%
sns.lmplot(
    data=processed_penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    height= 10,
    hue= 'species'
)

# %% [markdown]
# ## Información de sesión

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fb8b09fe-58e5-4e41-98af-4532009b73b8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
